# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# ## Athletes dataframe

# %%
athletes = pd.read_csv("data/olympic_athletes.csv", sep = ';')

# %%
def nan_to_0(row):
    if math.isnan(row):
        return 0
    else:
        return row
    
def nan_to_NA(row):
    if type(row) == str:
        return row
    elif math.isnan(row):
        return 'NA'

def nan_to_NA_or_int(row):
    if math.isnan(row):
        return 'NA'
    elif isinstance(row, float):
        return int(row)


athletes.G = athletes.G.apply(lambda x: nan_to_0(x))
athletes.S = athletes.S.apply(lambda x: nan_to_0(x))
athletes.B = athletes.B.apply(lambda x: nan_to_0(x))

athletes.first_game = athletes.first_game.apply(lambda x: nan_to_NA(x)) 
athletes.athlete_year_birth = athletes.athlete_year_birth.apply(lambda x: nan_to_NA_or_int(x))

# %%
with open('insert_athletes.txt', 'w', encoding="utf-8") as f:
    for row in athletes.iterrows():
        url, name, partecipations, first_game, birth, G, S, B = row[1]
        attrs = f'''name:"{name}", url:'{url}', games_participations:{partecipations}'''
        if first_game != 'NA':
            attrs += f", first_game:'{first_game}'"
        if birth != 'NA':
            attrs += f", birth_year:{birth}"
        if G !=0:
            attrs += f", gold:{int(G)}"
        if S !=0:
            attrs += f", silver:{int(S)}"
        if B !=0:
            attrs += f", bronze:{int(B)}"
        new_row = f'''CREATE (:Athlete \u007B{attrs}\u007D)\n'''
    
        f.write(new_row)

# %% [markdown]
# ## Hosts dataframe

# %%
hosts = pd.read_csv("data/olympic_hosts.csv", sep = ',')

# %%
with open('insert_hosts.txt', 'w', encoding="utf-8") as f:
    for row in hosts.iterrows():
        slug, end_date, start_date, location, name, season, year = row[1]
        new_row = f'''CREATE (:Host \u007B{f"game_slug:'{slug}', end_date:{end_date}, start_date:{start_date}, name:'{name}', season:'{season}', year:{year}"}\u007D)\n'''
        f.write(new_row)

# %% [markdown]
# ## Medals dataframe

# %%
medals = pd.read_csv("data/olympic_medals.csv", sep = ';')

# %%
medals
# Out:
#       discipline_title     slug_game                      event_title  \
# 0              Curling  beijing-2022                    Mixed Doubles
# 1              Curling  beijing-2022                    Mixed Doubles
# 2              Curling  beijing-2022                    Mixed Doubles
# 3              Curling  beijing-2022                    Mixed Doubles
# 4              Curling  beijing-2022                    Mixed Doubles
# ...                ...           ...                              ...
# 21692    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21693    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21694    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21695    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21696    Weightlifting   athens-1896  heavyweight - two hand lift men
#
#       event_gender medal_type participant_type participant_title  \
# 0            Mixed       GOLD         GameTeam             Italy
# 1            Mixed       GOLD         GameTeam             Italy
# 2            Mixed     SILVER         GameTeam            Norway
# 3            Mixed     SILVER         GameTeam            Norway
# 4            Mixed     BRONZE         GameTeam            Sweden
# ...            ...        ...              ...               ...
# 21692          Men     SILVER          Athlete               NaN
# 21693          Men     BRONZE          Athlete               NaN
# 21694          Men       GOLD          Athlete               NaN
# 21695          Men     SILVER          Athlete               NaN
# 21696          Men     BRONZE          Athlete               NaN
#
#                        athlete   country_name country_code
# 0         Stefania CONSTANTINI          Italy          ITA
# 1                 Amos MOSANER          Italy          ITA
# 2             Kristin SKASLIEN         Norway          NOR
# 3           Magnus NEDREGOTTEN         Norway          NOR
# 4                Almida DE VAL         Sweden          SWE
# ...                        ...            ...          ...
# 21692             Viggo JENSEN        Denmark          DEN
# 21693  Alexandros Nikolopoulos         Greece          GRE
# 21694             Viggo JENSEN        Denmark          DEN
# 21695        Launceston ELLIOT  Great Britain          GBR
# 21696          Sotirios VERSIS         Greece          GRE
#
# [21697 rows x 10 columns]

# %%
medals.isna().any()
# Out:
# discipline_title     False
# slug_game            False
# event_title          False
# event_gender         False
# medal_type           False
# participant_type     False
# participant_title     True
# athlete               True
# country_name          True
# country_code          True
# dtype: bool

# %%
# Create country instances.
countries = medals[['country_name', 'country_code']].dropna().drop_duplicates()

with open('insert_countries.txt', 'w', encoding="utf-8") as f:
    for row in countries.iterrows():
        name, code = row[1]
        attrs = f'''name:"{name}", code:"{code}"'''
        new_row = f'''CREATE (:Country \u007B{attrs}\u007D)\n'''
        f.write(new_row)

# %%
# Create event_title instances.

events =

# %%
# create discipline_title instance
# create event_title instance

medals
# Out:
#       discipline_title     slug_game                      event_title  \
# 0              Curling  beijing-2022                    Mixed Doubles
# 1              Curling  beijing-2022                    Mixed Doubles
# 2              Curling  beijing-2022                    Mixed Doubles
# 3              Curling  beijing-2022                    Mixed Doubles
# 4              Curling  beijing-2022                    Mixed Doubles
# ...                ...           ...                              ...
# 21692    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21693    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21694    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21695    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21696    Weightlifting   athens-1896  heavyweight - two hand lift men
#
#       event_gender medal_type participant_type participant_title  \
# 0            Mixed       GOLD         GameTeam             Italy
# 1            Mixed       GOLD         GameTeam             Italy
# 2            Mixed     SILVER         GameTeam            Norway
# 3            Mixed     SILVER         GameTeam            Norway
# 4            Mixed     BRONZE         GameTeam            Sweden
# ...            ...        ...              ...               ...
# 21692          Men     SILVER          Athlete               NaN
# 21693          Men     BRONZE          Athlete               NaN
# 21694          Men       GOLD          Athlete               NaN
# 21695          Men     SILVER          Athlete               NaN
# 21696          Men     BRONZE          Athlete               NaN
#
#                        athlete   country_name country_code
# 0         Stefania CONSTANTINI          Italy          ITA
# 1                 Amos MOSANER          Italy          ITA
# 2             Kristin SKASLIEN         Norway          NOR
# 3           Magnus NEDREGOTTEN         Norway          NOR
# 4                Almida DE VAL         Sweden          SWE
# ...                        ...            ...          ...
# 21692             Viggo JENSEN        Denmark          DEN
# 21693  Alexandros Nikolopoulos         Greece          GRE
# 21694             Viggo JENSEN        Denmark          DEN
# 21695        Launceston ELLIOT  Great Britain          GBR
# 21696          Sotirios VERSIS         Greece          GRE
#
# [21697 rows x 10 columns]

# %% [markdown]
# ## Results dataframe

# %%
results = pd.read_csv("data/olympic_results.csv", sep = ';')

# %%
results
# Out:
#            discipline_title  \
# 0                   Curling
# 1                   Curling
# 2                   Curling
# 3                   Curling
# 4                   Curling
# ...                     ...
# 162799          Ski Jumping
# 162800          Ski Jumping
# 162801          Ski Jumping
# 162802          Ski Jumping
# 162803  Gymnastics Artistic
#
#                                               event_title      slug_game  \
# 0                                           Mixed Doubles   beijing-2022
# 1                                           Mixed Doubles   beijing-2022
# 2                                           Mixed Doubles   beijing-2022
# 3                                           Mixed Doubles   beijing-2022
# 4                                           Mixed Doubles   beijing-2022
# ...                                                   ...            ...
# 162799                         Normal Hill Individual men  chamonix-1924
# 162800                         Normal Hill Individual men  chamonix-1924
# 162801                         Normal Hill Individual men  chamonix-1924
# 162802                         Normal Hill Individual men  chamonix-1924
# 162803  26th Federal Festival, Society and Association...     paris-1900
#
#        participant_type medal_type  \
# 0              GameTeam       GOLD
# 1              GameTeam     SILVER
# 2              GameTeam     BRONZE
# 3              GameTeam        NaN
# 4              GameTeam        NaN
# ...                 ...        ...
# 162799          Athlete        NaN
# 162800          Athlete        NaN
# 162801          Athlete        NaN
# 162802          Athlete        NaN
# 162803         GameTeam        NaN
#
#                                                  athletes rank_position  \
# 0       [('Stefania CONSTANTINI', 'https://olympics.co...             1
# 1       [('Kristin SKASLIEN', 'https://olympics.com/en...             2
# 2       [('Almida DE VAL', 'https://olympics.com/en/at...             3
# 3       [('Jennifer DODDS', 'https://olympics.com/en/a...             4
# 4       [('Rachel HOMAN', 'https://olympics.com/en/ath...             5
# ...                                                   ...           ...
# 162799  [('Franciszek BUJAK','https://olympics.com/en/...           DNS
# 162800                     [('Henryk Mückenbrunn','nan')]           DNS
# 162801                         [('Milda Prokopec','nan')]           DNS
# 162802                          [('Sigurd Overby','nan')]           DNS
# 162803                                                NaN             1
#
#                     country_name country_code
# 0                          Italy          ITA
# 1                         Norway          NOR
# 2                         Sweden          SWE
# 3                  Great Britain          GBR
# 4                         Canada          CAN
# ...                          ...          ...
# 162799                    Poland          POL
# 162800                    Poland          POL
# 162801            Czechoslovakia          TCH
# 162802  United States of America          USA
# 162803                    France          FRA
#
# [162804 rows x 9 columns]

# %%
# Function to get name and url of each athlete as a list in results.athletes.
def find_tuple_athl_url(row):
    if row is not np.nan:
        split_row = row.split("'")[1::2]
        tuple_list = []
        for name,  url in zip(split_row[::2], split_row[1::2]):
            tuple_list.append((name, url))
    else:
        return np.nan
    
    return tuple_list


results.athletes = results.athletes.apply(lambda x: find_tuple_athl_url(x))
